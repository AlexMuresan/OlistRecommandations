# %%
import os

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from IPython.display import display, display_html, Markdown


sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.set(style="ticks", context="talk")
plt.style.use("dark_background")

# %%
pd.__version__
# Out:
# '1.4.1'

# %%
def display_side_by_side(*args):
    html_str=''
    for df in args:
        html_str+=df.to_html()
    display_html(html_str.replace('table','table style="display:inline"'),raw=True)

# %%
display(Markdown('### Pandas inner merge on column - example'))
df1 = pd.DataFrame({'order_id': ['o1', 'o2', 'o3', 'o4', 'o5'],
                    'customer_id': ['c1', 'c2', 'c2', 'c3', 'c4']})
df2 = pd.DataFrame({'order_id': ['o1', 'o1', 'o2', 'o3', 'o4', 'o4', 'o5'],
                    'product_id': ['p1', 'p2', 'p1', 'p3', 'p4', 'p5', 'p5']})
merge_df = pd.merge(df1, df2, on='order_id', how='inner')

display(Markdown('#### df1 + df2 -> merged df'))
display_side_by_side(df1, df2, merge_df)

# display(Markdown('#### merged dfs'))
# display(merge_df)
# Out:
# ### Pandas inner merge on column - example
# #### df1 + df2 -> merged df
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>order_id</th>
#       <th>customer_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>o1</td>
#       <td>c1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>o2</td>
#       <td>c2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>o3</td>
#       <td>c2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>o4</td>
#       <td>c3</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>o5</td>
#       <td>c4</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>order_id</th>
#       <th>product_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>o1</td>
#       <td>p1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>o1</td>
#       <td>p2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>o2</td>
#       <td>p1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>o3</td>
#       <td>p3</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>o4</td>
#       <td>p4</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>o4</td>
#       <td>p5</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>o5</td>
#       <td>p5</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>order_id</th>
#       <th>customer_id</th>
#       <th>product_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>o1</td>
#       <td>c1</td>
#       <td>p1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>o1</td>
#       <td>c1</td>
#       <td>p2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>o2</td>
#       <td>c2</td>
#       <td>p1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>o3</td>
#       <td>c2</td>
#       <td>p3</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>o4</td>
#       <td>c3</td>
#       <td>p4</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>o4</td>
#       <td>c3</td>
#       <td>p5</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>o5</td>
#       <td>c4</td>
#       <td>p5</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %%
data_folder = '/Users/alex/Workspace/Datasets/OlistEcommercePublicDataset'

orders_df = pd.read_csv(os.path.join(data_folder, 'olist_orders_dataset.csv'))
reviews_df = pd.read_csv(os.path.join(data_folder, 'olist_order_reviews_dataset.csv'))
products_df = pd.read_csv(os.path.join(data_folder, 'olist_products_dataset.csv'))
order_items_df = pd.read_csv(os.path.join(data_folder, 'olist_order_items_dataset.csv'))
customer_df = pd.read_csv(os.path.join(data_folder, 'olist_customers_dataset.csv'))

# %%
display(orders_df[['order_id', 'customer_id']].head())
display(customer_df[['customer_id', 'customer_unique_id']].head())
# Out:
#                            order_id                       customer_id
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#                         customer_id                customer_unique_id
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066

# %%
# from orders_df -> order_id, customer_id
# from customer_df -> customer_id, customer_unique_id
unique_id_df = pd.merge(orders_df[['order_id', 'customer_id']], customer_df[['customer_id', 'customer_unique_id']], on=['customer_id'], how='inner')
display(unique_id_df.head())
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#                  customer_unique_id
# 0  7c396fd4830fd04220f754e42b4e5bff
# 1  af07308b275d755c9edb36a90c618231
# 2  3a653a41f6f9fc3d2a113cf8398680e8
# 3  7c142cf63193a1473d2e66489a9ae977
# 4  72632f0f9dd73dfee390c9b22eb56dd6

# %%
display(orders_df[['order_id', 'customer_id']].head())
display(products_df[['product_id']].head())
display(order_items_df[['order_id', 'product_id']].head())
# Out:
#                            order_id                       customer_id
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#                          product_id
# 0  1e9e8ef04dbcff4541ed26657ea517e5
# 1  3aa071139cb16b67ca9e5dea641aaa2f
# 2  96bd76ec8810374ed1b65e291975717f
# 3  cef67bcfe19066a932b7673e239eb23d
# 4  9dc1a7de274444849c219cff195d0b71
#                            order_id                        product_id
# 0  00010242fe8c5a6d1ba2dd792cb16214  4244733e06e7ecb4970a6e2683c13e61
# 1  00018f77f2f0320c557190d7a144bdd3  e5f2d52b802189ee658865ca93d83a8f
# 2  000229ec398224ef6ca0657da4fc703e  c777355d18b72b67abbeef9df44fd0fd
# 3  00024acbcdf0a6daa1e931b038114c75  7634da152a4610f1595efa32f14722fc
# 4  00042b26cf59d7ce69dfabb4e55b4fd9  ac6c3623068f30de03045865e4e10089

# %%
product_and_order_id_df = pd.merge(orders_df[['order_id', 'customer_id']], order_items_df[['order_id', 'product_id']], on=['order_id'], how='inner')
display(product_and_order_id_df.head())
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#                          product_id
# 0  87285b34884572647811a353c7ac498a
# 1  595fac2a385ac33a80bd5114aec74eb8
# 2  aa4383b373c6aca5d8797843e5594415
# 3  d0b61bfb1de832b15ba9d266ca96e5b0
# 4  65266b2da20d04dbe00c5c2d3bb7859e

# %%
user_product_order_id_df = pd.merge(unique_id_df, product_and_order_id_df, on=['order_id', 'customer_id'], how='inner')
display(user_product_order_id_df.head())
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#                  customer_unique_id                        product_id
# 0  7c396fd4830fd04220f754e42b4e5bff  87285b34884572647811a353c7ac498a
# 1  af07308b275d755c9edb36a90c618231  595fac2a385ac33a80bd5114aec74eb8
# 2  3a653a41f6f9fc3d2a113cf8398680e8  aa4383b373c6aca5d8797843e5594415
# 3  7c142cf63193a1473d2e66489a9ae977  d0b61bfb1de832b15ba9d266ca96e5b0
# 4  72632f0f9dd73dfee390c9b22eb56dd6  65266b2da20d04dbe00c5c2d3bb7859e

# %%
display(reviews_df[['order_id', 'review_score']].head())
# Out:
#                            order_id  review_score
# 0  73fc7af87114b39712e6da79b0a377eb             4
# 1  a548910a1c6147796b98fdf73dbeba33             5
# 2  f9e4b658b201a9f2ecdecbb34bed034b             5
# 3  658677c97b385a9be170737859d3511b             5
# 4  8e6bfb81e283fa7e4f11123a3fb894f1             5

# %%
final_df = pd.merge(user_product_order_id_df, reviews_df[['order_id', 'review_score']], on=['order_id'], how='inner').drop(['customer_id', 'order_id'], axis=1)
display(final_df.head())
# Out:
#                  customer_unique_id                        product_id  \
# 0  7c396fd4830fd04220f754e42b4e5bff  87285b34884572647811a353c7ac498a
# 1  af07308b275d755c9edb36a90c618231  595fac2a385ac33a80bd5114aec74eb8
# 2  3a653a41f6f9fc3d2a113cf8398680e8  aa4383b373c6aca5d8797843e5594415
# 3  7c142cf63193a1473d2e66489a9ae977  d0b61bfb1de832b15ba9d266ca96e5b0
# 4  72632f0f9dd73dfee390c9b22eb56dd6  65266b2da20d04dbe00c5c2d3bb7859e
#
#    review_score
# 0             4
# 1             4
# 2             5
# 3             5
# 4             5

# %%
customer_id_dict = final_df['customer_unique_id'].to_dict()
product_id_dict = final_df['product_id'].to_dict()

customer_id_dict = {v: k for k, v in customer_id_dict.items()}
product_id_dict = {v: k for k, v in product_id_dict.items()}

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/alex/Workspace/work/CollaborativeFiltering/OlistRecommandations/ratings_matrix_builder.ipynb Cell 14' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/alex/Workspace/work/CollaborativeFiltering/OlistRecommandations/ratings_matrix_builder.ipynb#ch0000019?line=0'>1</a> final_df_2 = final_df.replace({'customer_unique_id': customer_id_dict, 'product_id': product_id_dict})
#
# File ~/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/frame.py:5276, in DataFrame.replace(self, to_replace, value, inplace, limit, regex, method)
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/frame.py?line=5265'>5266</a> @doc(NDFrame.replace, **_shared_doc_kwargs)
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/frame.py?line=5266'>5267</a> def replace(
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/frame.py?line=5267'>5268</a>     self,
#    (...)
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/frame.py?line=5273'>5274</a>     method: str | lib.NoDefault = lib.no_default,
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/frame.py?line=5274'>5275</a> ):
# -> <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/frame.py?line=5275'>5276</a>     return super().replace(
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/frame.py?line=5276'>5277</a>         to_replace=to_replace,
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/frame.py?line=5277'>5278</a>         value=value,
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/frame.py?line=5278'>5279</a>         inplace=inplace,
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/frame.py?line=5279'>5280</a>         limit=limit,
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/frame.py?line=5280'>5281</a>         regex=regex,
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/frame.py?line=5281'>5282</a>         method=method,
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/frame.py?line=5282'>5283</a>     )
#
# File ~/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/generic.py:6659, in NDFrame.replace(self, to_replace, value, inplace, limit, regex, method)
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/generic.py?line=6655'>6656</a>     else:
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/generic.py?line=6656'>6657</a>         to_replace, value = keys, values
# -> <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/generic.py?line=6658'>6659</a>     return self.replace(
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/generic.py?line=6659'>6660</a>         to_replace, value, inplace=inplace, limit=limit, regex=regex
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/generic.py?line=6660'>6661</a>     )
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/generic.py?line=6661'>6662</a> else:
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/generic.py?line=6662'>6663</a>
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/generic.py?line=6663'>6664</a>     # need a non-zero len on all axes
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/generic.py?line=6664'>6665</a>     if not self.size:
#
# File ~/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/frame.py:5276, in DataFrame.replace(self, to_replace, value, inplace, limit, regex, method)
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/frame.py?line=5265'>5266</a> @doc(NDFrame.replace, **_shared_doc_kwargs)
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/frame.py?line=5266'>5267</a> def replace(
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/frame.py?line=5267'>5268</a>     self,
#    (...)
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/frame.py?line=5273'>5274</a>     method: str | lib.NoDefault = lib.no_default,
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/frame.py?line=5274'>5275</a> ):
# -> <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/frame.py?line=5275'>5276</a>     return super().replace(
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/frame.py?line=5276'>5277</a>         to_replace=to_replace,
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/frame.py?line=5277'>5278</a>         value=value,
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/frame.py?line=5278'>5279</a>         inplace=inplace,
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/frame.py?line=5279'>5280</a>         limit=limit,
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/frame.py?line=5280'>5281</a>         regex=regex,
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/frame.py?line=5281'>5282</a>         method=method,
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/frame.py?line=5282'>5283</a>     )
#
# File ~/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/generic.py:6679, in NDFrame.replace(self, to_replace, value, inplace, limit, regex, method)
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/generic.py?line=6670'>6671</a> if is_dict_like(value):  # {'A' : NA} -> {'A' : 0}
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/generic.py?line=6671'>6672</a>     # Note: Checking below for `in foo.keys()` instead of
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/generic.py?line=6672'>6673</a>     #  `in foo` is needed for when we have a Series and not dict
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/generic.py?line=6673'>6674</a>     mapping = {
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/generic.py?line=6674'>6675</a>         col: (to_replace[col], value[col])
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/generic.py?line=6675'>6676</a>         for col in to_replace.keys()
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/generic.py?line=6676'>6677</a>         if col in value.keys() and col in self
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/generic.py?line=6677'>6678</a>     }
# -> <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/generic.py?line=6678'>6679</a>     return self._replace_columnwise(mapping, inplace, regex)
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/generic.py?line=6680'>6681</a> # {'A': NA} -> 0
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/generic.py?line=6681'>6682</a> elif not is_list_like(value):
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/generic.py?line=6682'>6683</a>     # Operate column-wise
#
# File ~/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/frame.py:5311, in DataFrame._replace_columnwise(self, mapping, inplace, regex)
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/frame.py?line=5307'>5308</a>         ser = self.iloc[:, i]
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/frame.py?line=5309'>5310</a>         target, value = mapping[ax[i]]
# -> <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/frame.py?line=5310'>5311</a>         newobj = ser.replace(target, value, regex=regex)
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/frame.py?line=5312'>5313</a>         res.iloc[:, i] = newobj
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/frame.py?line=5314'>5315</a> if inplace:
#
# File ~/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/series.py:4960, in Series.replace(self, to_replace, value, inplace, limit, regex, method)
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/series.py?line=4944'>4945</a> @doc(
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/series.py?line=4945'>4946</a>     NDFrame.replace,  # type: ignore[has-type]
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/series.py?line=4946'>4947</a>     klass=_shared_doc_kwargs["klass"],
#    (...)
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/series.py?line=4957'>4958</a>     method: str | lib.NoDefault = lib.no_default,
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/series.py?line=4958'>4959</a> ):
# -> <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/series.py?line=4959'>4960</a>     return super().replace(
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/series.py?line=4960'>4961</a>         to_replace=to_replace,
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/series.py?line=4961'>4962</a>         value=value,
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/series.py?line=4962'>4963</a>         inplace=inplace,
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/series.py?line=4963'>4964</a>         limit=limit,
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/series.py?line=4964'>4965</a>         regex=regex,
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/series.py?line=4965'>4966</a>         method=method,
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/series.py?line=4966'>4967</a>     )
#
# File ~/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/generic.py:6708, in NDFrame.replace(self, to_replace, value, inplace, limit, regex, method)
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/generic.py?line=6702'>6703</a>     if len(to_replace) != len(value):
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/generic.py?line=6703'>6704</a>         raise ValueError(
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/generic.py?line=6704'>6705</a>             f"Replacement lists must match in length. "
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/generic.py?line=6705'>6706</a>             f"Expecting {len(to_replace)} got {len(value)} "
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/generic.py?line=6706'>6707</a>         )
# -> <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/generic.py?line=6707'>6708</a>     new_data = self._mgr.replace_list(
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/generic.py?line=6708'>6709</a>         src_list=to_replace,
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/generic.py?line=6709'>6710</a>         dest_list=value,
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/generic.py?line=6710'>6711</a>         inplace=inplace,
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/generic.py?line=6711'>6712</a>         regex=regex,
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/generic.py?line=6712'>6713</a>     )
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/generic.py?line=6714'>6715</a> elif to_replace is None:
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/generic.py?line=6715'>6716</a>     if not (
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/generic.py?line=6716'>6717</a>         is_re_compilable(regex)
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/generic.py?line=6717'>6718</a>         or is_list_like(regex)
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/generic.py?line=6718'>6719</a>         or is_dict_like(regex)
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/generic.py?line=6719'>6720</a>     ):
#
# File ~/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/managers.py:458, in BaseBlockManager.replace_list(self, src_list, dest_list, inplace, regex)
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/managers.py?line=454'>455</a> """do a list replace"""
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/managers.py?line=455'>456</a> inplace = validate_bool_kwarg(inplace, "inplace")
# --> <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/managers.py?line=457'>458</a> bm = self.apply(
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/managers.py?line=458'>459</a>     "replace_list",
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/managers.py?line=459'>460</a>     src_list=src_list,
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/managers.py?line=460'>461</a>     dest_list=dest_list,
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/managers.py?line=461'>462</a>     inplace=inplace,
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/managers.py?line=462'>463</a>     regex=regex,
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/managers.py?line=463'>464</a> )
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/managers.py?line=464'>465</a> bm._consolidate_inplace()
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/managers.py?line=465'>466</a> return bm
#
# File ~/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/managers.py:304, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/managers.py?line=301'>302</a>         applied = b.apply(f, **kwargs)
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/managers.py?line=302'>303</a>     else:
# --> <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/managers.py?line=303'>304</a>         applied = getattr(b, f)(**kwargs)
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/managers.py?line=304'>305</a> except (TypeError, NotImplementedError):
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/managers.py?line=305'>306</a>     if not ignore_failures:
#
# File ~/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py:813, in Block.replace_list(self, src_list, dest_list, inplace, regex)
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=809'>810</a>     assert not isinstance(mib, bool)
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=810'>811</a>     m = mib[blk_num : blk_num + 1]
# --> <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=812'>813</a> result = blk._replace_coerce(
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=813'>814</a>     to_replace=src,
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=814'>815</a>     value=dest,
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=815'>816</a>     mask=m,
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=816'>817</a>     inplace=inplace,
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=817'>818</a>     regex=regex,
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=818'>819</a> )
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=819'>820</a> if convert and blk.is_object and not all(x is None for x in dest_list):
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=820'>821</a>     # GH#44498 avoid unwanted cast-back
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=821'>822</a>     result = extend_blocks(
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=822'>823</a>         [b.convert(numeric=False, copy=True) for b in result]
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=823'>824</a>     )
#
# File ~/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py:868, in Block._replace_coerce(self, to_replace, value, mask, inplace, regex)
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=859'>860</a>     return self._replace_regex(
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=860'>861</a>         to_replace,
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=861'>862</a>         value,
#    (...)
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=864'>865</a>         mask=mask,
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=865'>866</a>     )
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=866'>867</a> else:
# --> <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=867'>868</a>     return self.replace(
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=868'>869</a>         to_replace=to_replace, value=value, inplace=inplace, mask=mask
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=869'>870</a>     )
#
# File ~/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py:695, in Block.replace(self, to_replace, value, inplace, mask)
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=690'>691</a> putmask_inplace(blk.values, mask, value)
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=691'>692</a> if not (self.is_object and value is None):
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=692'>693</a>     # if the user *explicitly* gave None, we keep None, otherwise
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=693'>694</a>     #  may downcast to NaN
# --> <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=694'>695</a>     blocks = blk.convert(numeric=False, copy=False)
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=695'>696</a> else:
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=696'>697</a>     blocks = [blk]
#
# File ~/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py:139, in maybe_split.<locals>.newfunc(self, *args, **kwargs)
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=134'>135</a> @wraps(meth)
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=135'>136</a> def newfunc(self, *args, **kwargs) -> list[Block]:
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=137'>138</a>     if self.ndim == 1 or self.shape[0] == 1:
# --> <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=138'>139</a>         return meth(self, *args, **kwargs)
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=139'>140</a>     else:
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=140'>141</a>         # Split and operate column-by-column
#     <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=141'>142</a>         return self.split_and_operate(meth, *args, **kwargs)
#
# File ~/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py:1918, in ObjectBlock.convert(self, copy, datetime, numeric, timedelta)
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=1912'>1913</a> if values.ndim == 2:
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=1913'>1914</a>     # maybe_split ensures we only get here with values.shape[0] == 1,
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=1914'>1915</a>     # avoid doing .ravel as that might make a copy
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=1915'>1916</a>     values = values[0]
# -> <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=1917'>1918</a> res_values = soft_convert_objects(
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=1918'>1919</a>     values,
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=1919'>1920</a>     datetime=datetime,
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=1920'>1921</a>     numeric=numeric,
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=1921'>1922</a>     timedelta=timedelta,
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=1922'>1923</a>     copy=copy,
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=1923'>1924</a> )
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=1924'>1925</a> res_values = ensure_block_shape(res_values, self.ndim)
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/internals/blocks.py?line=1925'>1926</a> return [self.make_block(res_values)]
#
# File ~/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/dtypes/cast.py:1343, in soft_convert_objects(values, datetime, numeric, timedelta, period, copy)
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/dtypes/cast.py?line=1338'>1339</a> if datetime or timedelta:
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/dtypes/cast.py?line=1339'>1340</a>     # GH 20380, when datetime is beyond year 2262, hence outside
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/dtypes/cast.py?line=1340'>1341</a>     # bound of nanosecond-resolution 64-bit integers.
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/dtypes/cast.py?line=1341'>1342</a>     try:
# -> <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/dtypes/cast.py?line=1342'>1343</a>         converted = lib.maybe_convert_objects(
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/dtypes/cast.py?line=1343'>1344</a>             values,
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/dtypes/cast.py?line=1344'>1345</a>             convert_datetime=datetime,
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/dtypes/cast.py?line=1345'>1346</a>             convert_timedelta=timedelta,
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/dtypes/cast.py?line=1346'>1347</a>             convert_period=period,
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/dtypes/cast.py?line=1347'>1348</a>         )
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/dtypes/cast.py?line=1348'>1349</a>     except (OutOfBoundsDatetime, ValueError):
#    <a href='file:///Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/dtypes/cast.py?line=1349'>1350</a>         return values
#
# KeyboardInterrupt:

# %%
rating_matrix = final_df.pivot_table(index='customer_unique_id', columns='product_id', values='review_score')
# Out:
# /Users/alex/miniconda3/envs/advanced/lib/python3.9/site-packages/pandas/core/reshape/reshape.py:134: PerformanceWarning: The following operation may generate 3105806869 cells in the resulting pandas object.
#   warnings.warn(

# %%
rating_matrix.to_hdf('rating_matrix.h5', key='rating_matrix')

# %%
rating_matrix.isnull().sum()
# Out:
# product_id
# 00066f42aeeb9f3007548bb9d3f33c38    94720
# 00088930e925c41fd95ebfe695fd2655    94720
# 0009406fd7479715e4bef61dd91f2462    94720
# 000b8f95fcb9e0096488278317764d19    94719
# 000d9be29b5207b54e86aa1b1ac54872    94720
#                                     ...
# fff6177642830a9a94a0f2cba5e476d1    94719
# fff81cc3158d2725c0655ab9ba0f712c    94720
# fff9553ac224cec9d15d49f5a263411f    94720
# fffdb2d0ec8d6a61f0a0a0db3f25b441    94716
# fffe9eeff12fcbd74a2f2b007dde0c58    94720
# Length: 32789, dtype: int64
